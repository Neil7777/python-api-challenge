# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 612

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "q=" + city + "&appid=" + weather_api_key + "&units=" + units
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | belyy yar
# Processing Record 3 of Set 1 | sabang
# Processing Record 4 of Set 1 | camabatela
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | papao
# Processing Record 7 of Set 1 | atafu village
# Processing Record 8 of Set 1 | prado
# Processing Record 9 of Set 1 | galt
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | weno
# Processing Record 12 of Set 1 | olonkinbyen
# Processing Record 13 of Set 1 | puerto natales
# Processing Record 14 of Set 1 | elmendorf air force base
# City not found. Skipping...
# Processing Record 15 of Set 1 | sekovici
# Processing Record 16 of Set 1 | gasa
# Processing Record 17 of Set 1 | las trojes
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | mount pearl
# Processing Record 20 of Set 1 | eagle point
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | adamstown
# Processing Record 23 of Set 1 | waitangi
# Processing Record 24 of Set 1 | edinburgh of the seven seas
# Processing Record 25 of Set 1 | anadyr
# Processing Record 26 of Set 1 | tsiombe
# Processing Record 27 of Set 1 | stanley
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | cascais
# Processing Record 30 of Set 1 | college
# Processing Record 31 of Set 1 | chonchi
# Processing Record 32 of Set 1 | happy valley-goose bay
# Processing Record 33 of Set 1 | corralillo
# Processing Record 34 of Set 1 | nemuro
# Processing Record 35 of Set 1 | tukrah
# Processing Record 36 of Set 1 | ko lanta
# Processing Record 37 of Set 1 | west island
# Processing Record 38 of Set 1 | iqaluit
# Processing Record 39 of Set 1 | laojunmiao
# Processing Record 40 of Set 1 | tsumeb
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | saudarkrokur
# Processing Record 44 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | salalah
# Processing Record 47 of Set 1 | mabaruma
# Processing Record 48 of Set 1 | polyarnyy
# Processing Record 49 of Set 1 | manatutu
# City not found. Skipping...
# Processing Record 50 of Set 1 | kolonia
# Processing Record 0 of Set 2 | blackmans bay
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | kayangel
# Processing Record 3 of Set 2 | kenora
# Processing Record 4 of Set 2 | wailua homesteads
# Processing Record 5 of Set 2 | judenburg
# Processing Record 6 of Set 2 | longyearbyen
# Processing Record 7 of Set 2 | alta
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | ust-nera
# Processing Record 10 of Set 2 | kosh-agach
# Processing Record 11 of Set 2 | gadzhiyevo
# Processing Record 12 of Set 2 | talnakh
# Processing Record 13 of Set 2 | mawlaik
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | pacific grove
# Processing Record 16 of Set 2 | puerto penasco
# Processing Record 17 of Set 2 | labytnangi
# Processing Record 18 of Set 2 | metlili chaamba
# Processing Record 19 of Set 2 | iskateley
# Processing Record 20 of Set 2 | piti village
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | ulanhot
# Processing Record 23 of Set 2 | hamilton
# Processing Record 24 of Set 2 | la passe
# Processing Record 25 of Set 2 | nova sintra
# Processing Record 26 of Set 2 | gallivare
# City not found. Skipping...
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | pyay
# Processing Record 29 of Set 2 | parasia
# Processing Record 30 of Set 2 | port glaud
# City not found. Skipping...
# Processing Record 31 of Set 2 | veraval
# Processing Record 32 of Set 2 | hawaiian paradise park
# Processing Record 33 of Set 2 | punta arenas
# Processing Record 34 of Set 2 | obock
# Processing Record 35 of Set 2 | farasan
# Processing Record 36 of Set 2 | renfrew
# Processing Record 37 of Set 2 | dampit
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | papatowai
# Processing Record 40 of Set 2 | aberdeen
# Processing Record 41 of Set 2 | rongelap
# Processing Record 42 of Set 2 | nikolayevsk-on-amure
# Processing Record 43 of Set 2 | klyuchi
# Processing Record 44 of Set 2 | fort irwin
# Processing Record 45 of Set 2 | constantia
# Processing Record 46 of Set 2 | point fortin
# Processing Record 47 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 48 of Set 2 | horta
# Processing Record 49 of Set 2 | thompson
# Processing Record 0 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 1 of Set 3 | destin
# Processing Record 2 of Set 3 | bereznik
# Processing Record 3 of Set 3 | espargos
# City not found. Skipping...
# Processing Record 4 of Set 3 | batang
# Processing Record 5 of Set 3 | greymouth
# Processing Record 6 of Set 3 | grenada
# Processing Record 7 of Set 3 | haiku-pauwela
# Processing Record 8 of Set 3 | san ignacio de velasco
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | axim
# Processing Record 11 of Set 3 | phang nga
# Processing Record 12 of Set 3 | dabou
# Processing Record 13 of Set 3 | invercargill
# Processing Record 14 of Set 3 | prince george
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | lewistown
# Processing Record 17 of Set 3 | igarka
# Processing Record 18 of Set 3 | oranjemund
# Processing Record 19 of Set 3 | soio
# Processing Record 20 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 21 of Set 3 | keita
# Processing Record 22 of Set 3 | fort bragg
# Processing Record 23 of Set 3 | badger
# Processing Record 24 of Set 3 | isafjordur
# Processing Record 25 of Set 3 | ghadamis
# Processing Record 26 of Set 3 | bogo
# Processing Record 27 of Set 3 | pangody
# Processing Record 28 of Set 3 | nar'yan-mar
# Processing Record 29 of Set 3 | the pas
# Processing Record 30 of Set 3 | monterey
# Processing Record 31 of Set 3 | kirillov
# Processing Record 32 of Set 3 | arteche
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | letlhakeng
# Processing Record 35 of Set 3 | masterton
# Processing Record 36 of Set 3 | ocean pointe
# City not found. Skipping...
# Processing Record 37 of Set 3 | kayyerkan
# Processing Record 38 of Set 3 | san antonio de pale
# Processing Record 39 of Set 3 | pasuquin
# Processing Record 40 of Set 3 | prineville
# Processing Record 41 of Set 3 | miri
# Processing Record 42 of Set 3 | yakeshi
# Processing Record 43 of Set 3 | vorgashor
# Processing Record 44 of Set 3 | luderitz
# Processing Record 45 of Set 3 | marsh harbour
# Processing Record 46 of Set 3 | kalmunai
# Processing Record 47 of Set 3 | selfoss
# Processing Record 48 of Set 3 | mount gambier
# Processing Record 49 of Set 3 | miles city
# Processing Record 0 of Set 4 | jutai
# Processing Record 1 of Set 4 | ketchikan
# Processing Record 2 of Set 4 | taltal
# Processing Record 3 of Set 4 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 4 of Set 4 | tura
# Processing Record 5 of Set 4 | gambela
# Processing Record 6 of Set 4 | ad dawadimi
# Processing Record 7 of Set 4 | dombarovskiy
# Processing Record 8 of Set 4 | nishinoomote
# Processing Record 9 of Set 4 | dauphin
# Processing Record 10 of Set 4 | lido di ostia
# Processing Record 11 of Set 4 | ad-damazin
# Processing Record 12 of Set 4 | kluczbork
# Processing Record 13 of Set 4 | bilibino
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | miranda
# Processing Record 16 of Set 4 | grand baie
# Processing Record 17 of Set 4 | vilyuchinsk
# Processing Record 18 of Set 4 | balikpapan
# Processing Record 19 of Set 4 | port elizabeth
# Processing Record 20 of Set 4 | choyr
# Processing Record 21 of Set 4 | isle of arran
# City not found. Skipping...
# Processing Record 22 of Set 4 | zapala
# Processing Record 23 of Set 4 | zouerate
# Processing Record 24 of Set 4 | turkeli
# Processing Record 25 of Set 4 | ozu
# Processing Record 26 of Set 4 | volchikha
# Processing Record 27 of Set 4 | cabo san lucas
# Processing Record 28 of Set 4 | fale old settlement
# Processing Record 29 of Set 4 | koesan
# Processing Record 30 of Set 4 | aasiaat
# Processing Record 31 of Set 4 | karratha
# Processing Record 32 of Set 4 | yanchep
# Processing Record 33 of Set 4 | berdigestyakh
# Processing Record 34 of Set 4 | san luis de la loma
# Processing Record 35 of Set 4 | vung tau
# Processing Record 36 of Set 4 | hauterive
# Processing Record 37 of Set 4 | sarupathar
# Processing Record 38 of Set 4 | ar rutbah
# Processing Record 39 of Set 4 | kodiak
# Processing Record 40 of Set 4 | saint-philippe
# Processing Record 41 of Set 4 | gizo
# Processing Record 42 of Set 4 | itaituba
# Processing Record 43 of Set 4 | whitehorse
# Processing Record 44 of Set 4 | villarrobledo
# Processing Record 45 of Set 4 | ardakan
# Processing Record 46 of Set 4 | marka
# Processing Record 47 of Set 4 | cockburn town
# Processing Record 48 of Set 4 | puerto eldorado
# Processing Record 49 of Set 4 | amga
# Processing Record 0 of Set 5 | olavarria
# Processing Record 1 of Set 5 | kerikeri
# Processing Record 2 of Set 5 | tazovsky
# Processing Record 3 of Set 5 | carnaiba
# Processing Record 4 of Set 5 | chanasma
# Processing Record 5 of Set 5 | hithadhoo
# Processing Record 6 of Set 5 | kingston
# Processing Record 7 of Set 5 | vila velha
# Processing Record 8 of Set 5 | ushuaia
# Processing Record 9 of Set 5 | san clemente
# Processing Record 10 of Set 5 | brookings
# Processing Record 11 of Set 5 | jamestown
# Processing Record 12 of Set 5 | osakarovka
# Processing Record 13 of Set 5 | yelizovo
# Processing Record 14 of Set 5 | ust'-kut
# Processing Record 15 of Set 5 | ben gardane
# Processing Record 16 of Set 5 | es castell
# Processing Record 17 of Set 5 | geroskipou
# City not found. Skipping...
# Processing Record 18 of Set 5 | naze
# Processing Record 19 of Set 5 | jabat
# Processing Record 20 of Set 5 | fada
# Processing Record 21 of Set 5 | sechura
# Processing Record 22 of Set 5 | tobruk
# Processing Record 23 of Set 5 | kondapalle
# Processing Record 24 of Set 5 | puerto leguizamo
# Processing Record 25 of Set 5 | kupino
# Processing Record 26 of Set 5 | tazacorte
# Processing Record 27 of Set 5 | trairi
# Processing Record 28 of Set 5 | margaret river
# Processing Record 29 of Set 5 | port mathurin
# Processing Record 30 of Set 5 | bentota
# Processing Record 31 of Set 5 | birjand
# Processing Record 32 of Set 5 | pisco
# Processing Record 33 of Set 5 | tinana
# City not found. Skipping...
# Processing Record 34 of Set 5 | touros
# Processing Record 35 of Set 5 | dindima
# Processing Record 36 of Set 5 | launceston
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | hastings
# Processing Record 39 of Set 5 | maxixe
# Processing Record 40 of Set 5 | conceicao das alagoas
# Processing Record 41 of Set 5 | kujang-up
# Processing Record 42 of Set 5 | ivins
# Processing Record 43 of Set 5 | fecamp
# Processing Record 44 of Set 5 | lompoc
# Processing Record 45 of Set 5 | kone
# Processing Record 46 of Set 5 | choibalsan
# Processing Record 47 of Set 5 | kapuskasing
# Processing Record 48 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 49 of Set 5 | hammerfest
# Processing Record 0 of Set 6 | shimanovsk
# Processing Record 1 of Set 6 | udachny
# Processing Record 2 of Set 6 | uturoa
# Processing Record 3 of Set 6 | cherepovets
# Processing Record 4 of Set 6 | emkhomazi
# Processing Record 5 of Set 6 | tibanbang
# Processing Record 6 of Set 6 | dudinka
# Processing Record 7 of Set 6 | at taj
# Processing Record 8 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 9 of Set 6 | yuzha
# Processing Record 10 of Set 6 | tolanaro
# Processing Record 11 of Set 6 | borogontsy
# Processing Record 12 of Set 6 | pankovka
# Processing Record 13 of Set 6 | kailua-kona
# Processing Record 14 of Set 6 | sisimiut
# Processing Record 15 of Set 6 | port isabel
# Processing Record 16 of Set 6 | furmanov
# Processing Record 17 of Set 6 | kaa-khem
# Processing Record 18 of Set 6 | usinsk
# Processing Record 19 of Set 6 | copala
# Processing Record 20 of Set 6 | el calafate
# Processing Record 21 of Set 6 | galliano
# Processing Record 22 of Set 6 | la ronge
# Processing Record 23 of Set 6 | hobyo
# Processing Record 24 of Set 6 | formosa do rio preto
# Processing Record 25 of Set 6 | aripuana
# Processing Record 26 of Set 6 | flin flon
# Processing Record 27 of Set 6 | andilamena
# Processing Record 28 of Set 6 | alvorada
# Processing Record 29 of Set 6 | tralee
# Processing Record 30 of Set 6 | kourou
# Processing Record 31 of Set 6 | sao joao de pirabas
# Processing Record 32 of Set 6 | labrador city
# Processing Record 33 of Set 6 | trusesti
# Processing Record 34 of Set 6 | utrik
# Processing Record 35 of Set 6 | san rafael
# Processing Record 36 of Set 6 | kasongo-lunda
# Processing Record 37 of Set 6 | keflavik
# Processing Record 38 of Set 6 | crane
# Processing Record 39 of Set 6 | lebanon
# Processing Record 40 of Set 6 | gereida
# Processing Record 41 of Set 6 | east london
# Processing Record 42 of Set 6 | whangarei
# Processing Record 43 of Set 6 | howrah
# Processing Record 44 of Set 6 | tadine
# Processing Record 45 of Set 6 | galle
# Processing Record 46 of Set 6 | callao
# Processing Record 47 of Set 6 | mount isa
# Processing Record 48 of Set 6 | macae
# Processing Record 49 of Set 6 | tan-tan
# Processing Record 0 of Set 7 | boda
# Processing Record 1 of Set 7 | mata-utu
# Processing Record 2 of Set 7 | magdagachi
# Processing Record 3 of Set 7 | yenifakili
# Processing Record 4 of Set 7 | jayapura
# Processing Record 5 of Set 7 | boromo
# Processing Record 6 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 7 | daru
# Processing Record 8 of Set 7 | i-n-salah
# Processing Record 9 of Set 7 | champerico
# Processing Record 10 of Set 7 | suva
# Processing Record 11 of Set 7 | mandan
# Processing Record 12 of Set 7 | itaqui
# Processing Record 13 of Set 7 | alice springs
# Processing Record 14 of Set 7 | nagqu
# Processing Record 15 of Set 7 | darwin
# Processing Record 16 of Set 7 | kiunga
# Processing Record 17 of Set 7 | bandarbeyla
# Processing Record 18 of Set 7 | barabai
# Processing Record 19 of Set 7 | acacias
# Processing Record 20 of Set 7 | zhangye
# Processing Record 21 of Set 7 | al kharijah
# Processing Record 22 of Set 7 | ilomantsi
# Processing Record 23 of Set 7 | kavaratti
# Processing Record 24 of Set 7 | uniao da vitoria
# Processing Record 25 of Set 7 | tippi
# Processing Record 26 of Set 7 | geraldton
# Processing Record 27 of Set 7 | qaqortoq
# Processing Record 28 of Set 7 | enewetak
# Processing Record 29 of Set 7 | usagara
# Processing Record 30 of Set 7 | bamboo flat
# Processing Record 31 of Set 7 | gamba
# Processing Record 32 of Set 7 | lampa
# Processing Record 33 of Set 7 | aykhal
# Processing Record 34 of Set 7 | maloye ganyushkino
# Processing Record 35 of Set 7 | filadelfia
# Processing Record 36 of Set 7 | sterling
# Processing Record 37 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 7 | fengxiang
# Processing Record 39 of Set 7 | chervyen'
# Processing Record 40 of Set 7 | tamandare
# Processing Record 41 of Set 7 | uaboe
# City not found. Skipping...
# Processing Record 42 of Set 7 | colonia
# Processing Record 43 of Set 7 | kununurra
# Processing Record 44 of Set 7 | plainview
# Processing Record 45 of Set 7 | knjazevac
# Processing Record 46 of Set 7 | kathmandu
# Processing Record 47 of Set 7 | holualoa
# Processing Record 48 of Set 7 | broken hill
# Processing Record 49 of Set 7 | st. john's
# Processing Record 0 of Set 8 | conception bay south
# Processing Record 1 of Set 8 | la mira
# Processing Record 2 of Set 8 | hargeysa
# Processing Record 3 of Set 8 | sur
# Processing Record 4 of Set 8 | hasaki
# Processing Record 5 of Set 8 | byron bay
# Processing Record 6 of Set 8 | claveria
# Processing Record 7 of Set 8 | quellon
# Processing Record 8 of Set 8 | buka
# Processing Record 9 of Set 8 | dolores
# Processing Record 10 of Set 8 | segorbe
# Processing Record 11 of Set 8 | bardai
# Processing Record 12 of Set 8 | tahe
# Processing Record 13 of Set 8 | sohar
# Processing Record 14 of Set 8 | port blair
# Processing Record 15 of Set 8 | ndende
# Processing Record 16 of Set 8 | falenki
# Processing Record 17 of Set 8 | susuman
# Processing Record 18 of Set 8 | bannu
# Processing Record 19 of Set 8 | lerwick
# Processing Record 20 of Set 8 | lodja
# Processing Record 21 of Set 8 | buala
# Processing Record 22 of Set 8 | zuunmod
# Processing Record 23 of Set 8 | kovdor
# Processing Record 24 of Set 8 | auce
# Processing Record 25 of Set 8 | afaahiti
# Processing Record 26 of Set 8 | yashkul'
# Processing Record 27 of Set 8 | laranjeiras do sul
# Processing Record 28 of Set 8 | lihue
# Processing Record 29 of Set 8 | pascagoula
# Processing Record 30 of Set 8 | tymovskoye
# Processing Record 31 of Set 8 | zhangatas
# Processing Record 32 of Set 8 | peniche
# Processing Record 33 of Set 8 | orchard homes
# Processing Record 34 of Set 8 | remire-montjoly
# Processing Record 35 of Set 8 | sinop
# Processing Record 36 of Set 8 | piacabucu
# Processing Record 37 of Set 8 | sola
# Processing Record 38 of Set 8 | coron
# Processing Record 39 of Set 8 | at taraf
# Processing Record 40 of Set 8 | neryungri
# Processing Record 41 of Set 8 | caleta de carquin
# Processing Record 42 of Set 8 | duluth
# Processing Record 43 of Set 8 | vadso
# Processing Record 44 of Set 8 | kataragama
# City not found. Skipping...
# Processing Record 45 of Set 8 | vorkuta
# Processing Record 46 of Set 8 | moyynkum
# Processing Record 47 of Set 8 | avenal
# Processing Record 48 of Set 8 | torquay
# Processing Record 49 of Set 8 | faya-largeau
# Processing Record 0 of Set 9 | arraial do cabo
# Processing Record 1 of Set 9 | cuyo
# Processing Record 2 of Set 9 | katsuren-haebaru
# Processing Record 3 of Set 9 | lycksele
# Processing Record 4 of Set 9 | yaren
# Processing Record 5 of Set 9 | candido mendes
# Processing Record 6 of Set 9 | rudnyy
# Processing Record 7 of Set 9 | kasane
# Processing Record 8 of Set 9 | northfield
# Processing Record 9 of Set 9 | colares
# Processing Record 10 of Set 9 | dickson
# Processing Record 11 of Set 9 | timbuktu
# Processing Record 12 of Set 9 | hotan
# Processing Record 13 of Set 9 | kirov
# Processing Record 14 of Set 9 | bereeda
# Processing Record 15 of Set 9 | tucupita
# Processing Record 16 of Set 9 | senador jose porfirio
# Processing Record 17 of Set 9 | khash
# Processing Record 18 of Set 9 | abu jibeha
# Processing Record 19 of Set 9 | salgareda
# Processing Record 20 of Set 9 | bikenibeu village
# Processing Record 21 of Set 9 | santa cruz
# Processing Record 22 of Set 9 | hermanus
# Processing Record 23 of Set 9 | damara
# Processing Record 24 of Set 9 | qulsary
# Processing Record 25 of Set 9 | amungan
# Processing Record 26 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 27 of Set 9 | garachico
# Processing Record 28 of Set 9 | port saint john's
# Processing Record 29 of Set 9 | inhambane
# Processing Record 30 of Set 9 | romentino
# Processing Record 31 of Set 9 | berezovo
# Processing Record 32 of Set 9 | awjilah
# Processing Record 33 of Set 9 | kushiro
# Processing Record 34 of Set 9 | mokopane
# Processing Record 35 of Set 9 | tofol
# Processing Record 36 of Set 9 | zhuanghe
# Processing Record 37 of Set 9 | leirvik
# Processing Record 38 of Set 9 | villa gesell
# Processing Record 39 of Set 9 | ijuw
# City not found. Skipping...
# Processing Record 40 of Set 9 | vernon
# Processing Record 41 of Set 9 | mahanoro
# Processing Record 42 of Set 9 | morondava
# Processing Record 43 of Set 9 | macusani
# Processing Record 44 of Set 9 | shimoda
# Processing Record 45 of Set 9 | el tigre
# Processing Record 46 of Set 9 | sitka
# Processing Record 47 of Set 9 | robertsport
# Processing Record 48 of Set 9 | luwuk
# Processing Record 49 of Set 9 | shiyan
# Processing Record 0 of Set 10 | twin falls
# Processing Record 1 of Set 10 | hirson
# Processing Record 2 of Set 10 | al wajh
# Processing Record 3 of Set 10 | sabt alalayah
# City not found. Skipping...
# Processing Record 4 of Set 10 | bansang
# Processing Record 5 of Set 10 | broome
# Processing Record 6 of Set 10 | verkhnevilyuysk
# Processing Record 7 of Set 10 | leava
# Processing Record 8 of Set 10 | san julian
# Processing Record 9 of Set 10 | sao joao dos patos
# Processing Record 10 of Set 10 | hengchun
# Processing Record 11 of Set 10 | abancay
# Processing Record 12 of Set 10 | cole harbour
# Processing Record 13 of Set 10 | sandnessjoen
# Processing Record 14 of Set 10 | cofradia
# Processing Record 15 of Set 10 | araxa
# Processing Record 16 of Set 10 | usogorsk
# Processing Record 17 of Set 10 | newman
# Processing Record 18 of Set 10 | dubbo
# Processing Record 19 of Set 10 | cannonvale
# Processing Record 20 of Set 10 | wa
# City not found. Skipping...
# Processing Record 21 of Set 10 | akureyri
# Processing Record 22 of Set 10 | thunder bay
# Processing Record 23 of Set 10 | andratx
# Processing Record 24 of Set 10 | bubaque
# Processing Record 25 of Set 10 | winnemucca
# Processing Record 26 of Set 10 | zeya
# Processing Record 27 of Set 10 | lakatoro
# Processing Record 28 of Set 10 | santa terezinha
# Processing Record 29 of Set 10 | ancud
# Processing Record 30 of Set 10 | strezhevoy
# Processing Record 31 of Set 10 | sabha
# Processing Record 32 of Set 10 | bonito
# Processing Record 33 of Set 10 | baiti
# Processing Record 34 of Set 10 | reggane
# Processing Record 35 of Set 10 | hisai-motomachi
# Processing Record 36 of Set 10 | praia da vitoria
# Processing Record 37 of Set 10 | rampura
# Processing Record 38 of Set 10 | sarikei
# Processing Record 39 of Set 10 | rehoboth
# Processing Record 40 of Set 10 | flying fish cove
# Processing Record 41 of Set 10 | terekeka
# City not found. Skipping...
# Processing Record 42 of Set 10 | bandiagara
# Processing Record 43 of Set 10 | esquel
# Processing Record 44 of Set 10 | chato
# Processing Record 45 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 46 of Set 10 | ascension
# Processing Record 47 of Set 10 | rye
# Processing Record 48 of Set 10 | waynesville
# Processing Record 49 of Set 10 | mermoz boabab
# Processing Record 0 of Set 11 | la gi
# Processing Record 1 of Set 11 | san jose del guaviare
# Processing Record 2 of Set 11 | strathalbyn
# Processing Record 3 of Set 11 | vanju-mare
# Processing Record 4 of Set 11 | aksu
# Processing Record 5 of Set 11 | vrangel'
# Processing Record 6 of Set 11 | smara
# Processing Record 7 of Set 11 | dumai
# Processing Record 8 of Set 11 | williams lake
# Processing Record 9 of Set 11 | itambacuri
# Processing Record 10 of Set 11 | cabugao
# Processing Record 11 of Set 11 | karanja
# Processing Record 12 of Set 11 | westport
# Processing Record 13 of Set 11 | ola
# Processing Record 14 of Set 11 | bakaly
# Processing Record 15 of Set 11 | mitha tiwana
# Processing Record 16 of Set 11 | felipe carrillo puerto
# Processing Record 17 of Set 11 | preobrazheniye
# Processing Record 18 of Set 11 | sao joao da barra
# Processing Record 19 of Set 11 | rocca priora
# Processing Record 20 of Set 11 | smithers
# Processing Record 21 of Set 11 | timbiqui
# Processing Record 22 of Set 11 | alaghsas
# Processing Record 23 of Set 11 | sheki
# Processing Record 24 of Set 11 | shahdol
# Processing Record 25 of Set 11 | lata
# Processing Record 26 of Set 11 | turkmenbasy
# Processing Record 27 of Set 11 | vanino
# Processing Record 28 of Set 11 | mugia
# Processing Record 29 of Set 11 | sandakan
# Processing Record 30 of Set 11 | moose jaw
# Processing Record 31 of Set 11 | guaruja
# Processing Record 32 of Set 11 | paita
# Processing Record 33 of Set 11 | egilsstadir
# Processing Record 34 of Set 11 | ambon
# Processing Record 35 of Set 11 | palu
# Processing Record 36 of Set 11 | madalena
# Processing Record 37 of Set 11 | tangalle
# Processing Record 38 of Set 11 | manay
# Processing Record 39 of Set 11 | minas de marcona
# Processing Record 40 of Set 11 | kasese
# Processing Record 41 of Set 11 | san-pedro
# Processing Record 42 of Set 11 | ghat
# Processing Record 43 of Set 11 | taytay
# Processing Record 44 of Set 11 | san patricio
# Processing Record 45 of Set 11 | salinopolis
# Processing Record 46 of Set 11 | saint joseph
# Processing Record 47 of Set 11 | manokwari
# Processing Record 48 of Set 11 | novo aripuana
# Processing Record 49 of Set 11 | saint-pierre
# Processing Record 0 of Set 12 | lamar
# Processing Record 1 of Set 12 | rikaze
# Processing Record 2 of Set 12 | nelson bay
# Processing Record 3 of Set 12 | manali
# Processing Record 4 of Set 12 | umatac village
# City not found. Skipping...
# Processing Record 5 of Set 12 | tataouine
# Processing Record 6 of Set 12 | cidreira
# Processing Record 7 of Set 12 | vilyuysk
# Processing Record 8 of Set 12 | kuta
# Processing Record 9 of Set 12 | zag
# Processing Record 10 of Set 12 | seybaplaya
# Processing Record 11 of Set 12 | onguday
# Processing Record 12 of Set 12 | altay
# Processing Record 13 of Set 12 | ndele
# Processing Record 14 of Set 12 | sumusta as sultani
# Processing Record 15 of Set 12 | mogadishu
# Processing Record 16 of Set 12 | ishigaki
# Processing Record 17 of Set 12 | las khorey
# Processing Record 18 of Set 12 | patterson
# Processing Record 19 of Set 12 | santa ana
# Processing Record 20 of Set 12 | betio village
# Processing Record 21 of Set 12 | hadibu
# Processing Record 22 of Set 12 | nakamura
# Processing Record 23 of Set 12 | sao felix do xingu
# Processing Record 24 of Set 12 | tezu
# Processing Record 25 of Set 12 | strangnas
# Processing Record 26 of Set 12 | howard springs
# Processing Record 27 of Set 12 | dryden
# Processing Record 28 of Set 12 | ghormach
# Processing Record 29 of Set 12 | savanna-la-mar
# Processing Record 30 of Set 12 | withernsea
# Processing Record 31 of Set 12 | fort mcmurray
# Processing Record 32 of Set 12 | bosaso
# Processing Record 33 of Set 12 | san mariano
# Processing Record 34 of Set 12 | batu pahat
# Processing Record 35 of Set 12 | cuatro cienegas de carranza
# Processing Record 36 of Set 12 | nynashamn
# Processing Record 37 of Set 12 | puerto baquerizo moreno
# Processing Record 38 of Set 12 | acapulco de juarez
# Processing Record 39 of Set 12 | ad dabbah
# Processing Record 40 of Set 12 | zhezqazghan
# Processing Record 41 of Set 12 | kimberley
# Processing Record 42 of Set 12 | la londe-les-maures
# Processing Record 43 of Set 12 | tam ky
# Processing Record 44 of Set 12 | santo tome
# Processing Record 45 of Set 12 | saipan
# Processing Record 46 of Set 12 | palikir - national government center
# Processing Record 47 of Set 12 | katabu
# Processing Record 48 of Set 12 | chos malal
# Processing Record 49 of Set 12 | vila franca do campo
# Processing Record 0 of Set 13 | novoazovs'k
# Processing Record 1 of Set 13 | namibe
# Processing Record 2 of Set 13 | tamanrasset
# Processing Record 3 of Set 13 | fortuna
# Processing Record 4 of Set 13 | la palma
# Processing Record 5 of Set 13 | moyale
# Processing Record 6 of Set 13 | aioun
# Processing Record 7 of Set 13 | katsuura
# Processing Record 8 of Set 13 | sakakah
# Processing Record 9 of Set 13 | maragogi
# Processing Record 10 of Set 13 | yemetsk
# Processing Record 11 of Set 13 | guatire
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          586
# Lat           586
# Lng           586
# Max Temp      586
# Humidity      586
# Cloudiness    586
# Wind Speed    586
# Country       586
# Date          586
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      4.64        79          85
# 1          belyy yar  53.6039   91.3903    -28.06        76          90
# 2             sabang   5.8933   95.3214     27.93        73          47
# 3         camabatela  -8.1881   15.3750     18.09       100         100
# 4        yellowknife  62.4560 -114.3525    -13.10        97          75
#
#    Wind Speed Country        Date
# 0        8.01      TF  1702276313
# 1        0.00      RU  1702276313
# 2        1.72      ID  1702276313
# 3        0.80      AO  1702276313
# 4        6.69      CA  1702276313

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      4.64        79          85
# 1                belyy yar  53.6039   91.3903    -28.06        76          90
# 2                   sabang   5.8933   95.3214     27.93        73          47
# 3               camabatela  -8.1881   15.3750     18.09       100         100
# 4              yellowknife  62.4560 -114.3525    -13.10        97          75
#
#          Wind Speed Country        Date
# City_ID
# 0              8.01      TF  1702276313
# 1              0.00      RU  1702276313
# 2              1.72      ID  1702276313
# 3              0.80      AO  1702276313
# 4              6.69      CA  1702276313

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_val = city_data_df["Lat"]
y_val = city_data_df["Max Temp"]

# Incorporate the other graph properties
plt.scatter(x_val, y_val, facecolors = "tab:blue", edgecolors= "black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Temparature (2023/10/12)")
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_val = city_data_df["Lat"]
y_val = city_data_df["Humidity"]

# Incorporate the other graph properties
plt.scatter(x_val, y_val, facecolors = "tab:blue", edgecolors= "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title("City Latitude vs. Humidity (2023/10/12)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_val = city_data_df["Lat"]
y_val = city_data_df["Cloudiness"]


# Incorporate the other graph properties
plt.scatter(x_val, y_val, facecolors = "tab:blue", edgecolors= "black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title("City Latitude vs. Cloudiness (2023/10/12)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_val = city_data_df["Lat"]
y_val = city_data_df["Wind Speed"]

# Incorporate the other graph properties
plt.scatter(x_val, y_val, facecolors = "tab:blue", edgecolors= "black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2023/10/12)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          belyy yar  53.6039   91.3903    -28.06        76          90
# 2             sabang   5.8933   95.3214     27.93        73          47
# 4        yellowknife  62.4560 -114.3525    -13.10        97          75
# 8               galt  38.2546 -121.3000     10.56        84         100
# 10              weno   7.4515  151.8468     29.97        74          75
#
#          Wind Speed Country        Date
# City_ID
# 1              0.00      RU  1702276313
# 2              1.72      ID  1702276313
# 4              6.69      CA  1702276313
# 8              1.72      US  1702276277
# 10             3.60      FM  1702276313

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      4.64        79          85
# 3               camabatela  -8.1881   15.3750     18.09       100         100
# 5                    papao -17.7500 -149.5500     27.82        81          39
# 6            atafu village  -8.5421 -172.5159     29.15        74         100
# 7                    prado -17.3411  -39.2208     22.54        94          20
#
#          Wind Speed Country        Date
# City_ID
# 0              8.01      TF  1702276313
# 3              0.80      AO  1702276313
# 5             11.70      PF  1702276313
# 6              5.74      TK  1702276313
# 7              2.25      BR  1702276015

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Max Temp"]
slope = linregress(x_val, y_val)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.868368094959821

# %%
# Linear regression on Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Max Temp"]
slope = linregress(x_val, y_val)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "-r")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.5936173702371884

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Humidity"]
slope = linregress(x_val, y_val)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "-r")
plt.annotate(line_eq,(45,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.4067184365674922

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Humidity"]
slope = linregress(x_val, y_val)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "-r")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.1480357779672706

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Cloudiness"]
slope = linregress(x_val, y_val)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "-r")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.33059363723553375

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Cloudiness"]
slope = linregress(x_val, y_val)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "-r")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.16907739472461816

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Wind Speed"]
slope = linregress(x_val, y_val)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "-r")
plt.annotate(line_eq,(20,13),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.11431823239392983

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Wind Speed"]
slope = linregress(x_val, y_val)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "-r")
plt.annotate(line_eq,(-50,11),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.18157578133542818

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
